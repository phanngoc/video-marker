# %% [markdown]
# # Mlxtend Library for Data Science
# https://ealizadeh.com/blog/mlxtend-library-for-data-science/

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.3-py3-none-any.whl.metadata (7.3 kB)
# Collecting scipy>=1.2.1 (from mlxtend)
#   Using cached scipy-1.14.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy>=1.16.2 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from mlxtend) (2.1.3)
# Collecting pandas>=0.24.2 (from mlxtend)
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting scikit-learn>=1.3.1 (from mlxtend)
#   Using cached scikit_learn-1.5.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting matplotlib>=3.0.0 (from mlxtend)
#   Downloading matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting joblib>=0.13.2 (from mlxtend)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0.0->mlxtend)
#   Downloading contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0.0->mlxtend)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0.0->mlxtend)
#   Downloading fonttools-4.55.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0.0->mlxtend)
#   Downloading kiwisolver-1.4.7-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=0.24.2->mlxtend)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.24.2->mlxtend)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.1->mlxtend)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/ngocp/Documents/projects/video-maker/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.4 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 7.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 8.4 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Using cached scikit_learn-1.5.2-cp310-cp310-macosx_12_0_arm64.whl (11.0 MB)
# Using cached scipy-1.14.1-cp310-cp310-macosx_12_0_arm64.whl (29.9 MB)
# Downloading contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.1 MB/s eta 0:00:009.2 MB/s eta 0:00:01
# Downloading kiwisolver-1.4.7-cp310-cp310-macosx_11_0_arm64.whl (64 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, scipy, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, pandas, matplotlib, mlxtend
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.0 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.2 mlxtend-0.23.3 pandas-2.2.3 pytz-2024.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0 tzdata-2024.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.data import iris_data
from mlxtend.plotting import plot_decision_regions

# Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = SVC(random_state=0, probability=True)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[2, 1, 1], voting='soft')

# %%
# Loading some example data
X, y = iris_data()
X = X[:,[0, 2]]

print(f'Shape of X: {X.shape}')
print(f'Shape of y: {y.shape}')
# Out:
# Shape of X: (150, 2)
# Shape of y: (150,)

# %%
# Plotting Decision Regions

gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression',
          'Random Forest',
          'RBF kernel SVM',
          'Ensemble']

for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1],
                         repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y,
                                clf=clf, legend=2)
    plt.title(lab)

plt.show()
